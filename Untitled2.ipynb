# %%
import pandas as pd

data = {
    "Dish": ["Pizza", "Burger", "Pizza", "Biryani"],
    "Sales": [500, 300, 400, 600]
}

df = pd.DataFrame(data)

print(df)
print("Total Sales =", df["Sales"].sum())
# Out:
#       Dish  Sales
# 0    Pizza    500
# 1   Burger    300
# 2    Pizza    400
# 3  Biryani    600
# Total Sales = 1800
